# %%
import iamend_ci as ci

# %% [markdown]
# ## Densidad:
#
# ```python
# jhf(r,z,I,f,bo,sigma,mur,lmax=1000):
# ```

# %%
exp1=ci.exp('/Users/fernando/Downloads/datos_perm_304-main/304_1')
# Out:
# z1 = 1.0360259829448746 mm

# %%
exp1.info
# Out:
#         archivo  conductividad   espesor bobina
# 0    0_aire.csv            0.0  0.000000     m1
# 1  1_patron.csv       612000.0  0.025000     m1
# 2  304_1_p1.csv      1040000.0  0.003737     m1
# 3  304_1_p2.csv      1060000.0  0.003818     m1
# 4  304_1_p3.csv      1140000.0  0.003842     m1
# 5  304_1_p4.csv      1240000.0  0.003877     m1
# 6  304_1_p5.csv      1260000.0  0.003899     m1
# 7  304_1_p6.csv      1310000.0  0.004105     m1

# %%
len(exp1.dzcorrnorm)
# Out:
# 6

# %%
exp1.muestras[0]
# Out:
# Muestra (304_1_p1.csv)

# %%
exp1.muestras[0].name
# Out:
# '304_1_p1.csv'

# %%
exp1.normcorr()

# %%
exp1.fitpatron()
# Out:
# z1 = 1.0360259829448746 mm

# %%
exp1.fitmues()
# Out:
# mu_r_eff = 1.0042262193481575
# mu_r_eff = 7.272184589802646
# mu_r_eff = 6.199932827423396
# mu_r_eff = 5.763565791685518
# mu_r_eff = 5.704608859642888
# mu_r_eff = 4.92852182416232
# mu_r_eff = 2.3434934438683177

# %%
exp1.info
# Out:
#      Unnamed: 0  conductividad   espesor bobina    mu_eff
# 0    0_aire.csv            0.0  0.000000     m1  0.000000
# 1  1_patron.csv       612000.0  0.025000     m1  1.004226
# 2  304_1_p1.csv      1040000.0  0.003737     m1  7.272185
# 3  304_1_p2.csv      1060000.0  0.003818     m1  6.199933
# 4  304_1_p3.csv      1140000.0  0.003842     m1  5.763566
# 5  304_1_p4.csv      1240000.0  0.003877     m1  5.704609
# 6  304_1_p5.csv      1260000.0  0.003899     m1  4.928522
# 7  304_1_p6.csv      1310000.0  0.004105     m1  2.343493

# %%
ci.theo.jhf
# Out:
# <function iamend_ci.theo.jhf(r, z, I, f, bo, sigma, mur, lmax=1000)>

# %%
exp1.files
# Out:
# 0      0_aire.csv
# 1    1_patron.csv
# 2    304_1_p1.csv
# 3    304_1_p2.csv
# 4    304_1_p3.csv
# 5    304_1_p4.csv
# 6    304_1_p5.csv
# 7    304_1_p6.csv
# Name: Unnamed: 0, dtype: object

# %%
len(exp1.dzcorrnorm)
# Out:
# 7

# %%
for x in exp1.files:
    if (not 'aire' in x) and (not 'patron' in x):
        print(x)
# Out:
# 304_1_p1.csv
# 304_1_p2.csv
# 304_1_p3.csv
# 304_1_p4.csv
# 304_1_p5.csv
# 304_1_p6.csv

# %%
[x for x in exp1.files  if (not 'aire' in x) and (not 'patron' in x) ]
# Out:
# ['304_1_p1.csv',
#  '304_1_p2.csv',
#  '304_1_p3.csv',
#  '304_1_p4.csv',
#  '304_1_p5.csv',
#  '304_1_p6.csv']
