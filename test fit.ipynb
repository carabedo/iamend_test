# %%
import iamend_ci as ci
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>

# %%
exp=ci.exp('./iamend_ci/datos/m1_347')
exp.fitmues()
# Out:
#                  archivo  conductividad   espesor bobina  muestras
# 0       Exp_347_Aire.csv           0.00  0.000000     m1      aire
# 1        Exp_347_M01.csv     1051184.21  0.022958     m1   347_M01
# 2        Exp_347_M02.csv     1118491.27  0.023400     m1   347_M02
# 3        Exp_347_M03.csv     1142610.84  0.022709     m1   347_M03
# 4        Exp_347_M04.csv     1216575.14  0.023400     m1   347_M04
# 5        Exp_347_M05.csv     1308978.66  0.023292     m1   347_M05
# 6        Exp_347_M06.csv     1371864.40  0.022150     m1   347_M06
# 7        Exp_347_M07.csv     1387902.82  0.023100     m1   347_M07
# 8        Exp_347_M08.csv     1415286.59  0.023025     m1   347_M08
# 9        Exp_347_M09.csv     1377247.16  0.022258     m1   347_M09
# 10       Exp_347_M11.csv     1432375.75  0.022430     m1   347_M11
# 11  Exp_347_Patron78.csv           0.00  0.000000     m1  Patron78
# 12  Exp_347_Patron80.csv           0.00  0.000000     m1  Patron80
# Ajustando z1 effectivo
# z1 = 1.1 mm

# %%
exp.info
# Out:
#                  archivo  conductividad   espesor bobina  muestras      mueff  \
# 0       Exp_347_Aire.csv           0.00  0.000000     m1      aire        NaN
# 1        Exp_347_M01.csv     1051184.21  0.022958     m1   347_M01  59.108312
# 2        Exp_347_M02.csv     1118491.27  0.023400     m1   347_M02  53.607504
# 3        Exp_347_M03.csv     1142610.84  0.022709     m1   347_M03  47.266664
# 4        Exp_347_M04.csv     1216575.14  0.023400     m1   347_M04  17.841392
# 5        Exp_347_M05.csv     1308978.66  0.023292     m1   347_M05   7.592585
# 6        Exp_347_M06.csv     1371864.40  0.022150     m1   347_M06   3.163659
# 7        Exp_347_M07.csv     1387902.82  0.023100     m1   347_M07   2.713330
# 8        Exp_347_M08.csv     1415286.59  0.023025     m1   347_M08   1.662739
# 9        Exp_347_M09.csv     1377247.16  0.022258     m1   347_M09   1.589715
# 10       Exp_347_M11.csv     1432375.75  0.022430     m1   347_M11   1.054879
# 11  Exp_347_Patron78.csv           0.00  0.000000     m1  Patron78        NaN
# 12  Exp_347_Patron80.csv           0.00  0.000000     m1  Patron80        NaN
#
#           R2
# 0        NaN
# 1   0.985397
# 2   0.974790
# 3   0.984895
# 4   0.996368
# 5   0.998162
# 6   0.994713
# 7   0.989405
# 8   0.997445
# 9   0.997746
# 10  0.997211
# 11       NaN
# 12       NaN

# %%
exp.muplot('m03')
# Out:
#   <div id="41019a1f-03d1-4afc-aaba-ff676379e993" data-root-id="p1002" style="display: contents;"></div>

# %%
exp.fitfmues(3)
# Out:
# fiteo en N tramos

# %%
exp.info
# Out:
#                  archivo  conductividad   espesor bobina  muestras      mueff  \
# 0       Exp_347_Aire.csv           0.00  0.000000     m1      aire        NaN
# 1        Exp_347_M01.csv     1051184.21  0.022958     m1   347_M01  59.108312
# 2        Exp_347_M02.csv     1118491.27  0.023400     m1   347_M02  53.607504
# 3        Exp_347_M03.csv     1142610.84  0.022709     m1   347_M03  47.266664
# 4        Exp_347_M04.csv     1216575.14  0.023400     m1   347_M04  17.841392
# 5        Exp_347_M05.csv     1308978.66  0.023292     m1   347_M05   7.592585
# 6        Exp_347_M06.csv     1371864.40  0.022150     m1   347_M06   3.163659
# 7        Exp_347_M07.csv     1387902.82  0.023100     m1   347_M07   2.713330
# 8        Exp_347_M08.csv     1415286.59  0.023025     m1   347_M08   1.662739
# 9        Exp_347_M09.csv     1377247.16  0.022258     m1   347_M09   1.589715
# 10       Exp_347_M11.csv     1432375.75  0.022430     m1   347_M11   1.054879
# 11  Exp_347_Patron78.csv           0.00  0.000000     m1  Patron78        NaN
# 12  Exp_347_Patron80.csv           0.00  0.000000     m1  Patron80        NaN
#
#           R2   mu 1k-10k  mu 12k-100k  mu 125k-1000k
# 0        NaN         NaN          NaN            NaN
# 1   0.985397  165.735724    69.619828      53.996322
# 2   0.974790  197.438645    67.224022      47.258611
# 3   0.984895  109.149614    54.615139      43.019748
# 4   0.996368   21.779035    18.486962      16.818388
# 5   0.998162    7.445541     7.845417       7.463003
# 6   0.994713    2.957116     3.406533       3.353224
# 7   0.989405    2.471484     2.875543       3.348211
# 8   0.997445    1.623970     1.733071       1.713139
# 9   0.997746    1.549652     1.642372       1.708174
# 10  0.997211    1.061461     1.047294       1.021334
# 11       NaN         NaN          NaN            NaN
# 12       NaN         NaN          NaN            NaN

# %%
exp.fmuplot('m01')
# Out:
#   <div id="ffd491b2-35b7-49cb-8964-a4b0667e8ab5" data-root-id="p1174" style="display: contents;"></div>

# %%
exp.fmuplot('m11')
# Out:
#   <div id="d605bcd5-c6e3-4970-86e7-db6b3efffa85" data-root-id="p1539" style="display: contents;"></div>

# %%
from bokeh.io import output_notebook, curdoc  # output_file
from bokeh.plotting import figure, show
from bokeh.layouts import row, column, gridplot
import numpy as np

# %%
output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1364">Loading BokehJS ...</span>
#     </div>

# %%
tool_list = ['box_zoom', 'reset']
altura=500
ancho=600
markers=["square",'triangle','circle','inverted_triangle']

# %%
muestra='m01'
muestra_name=exp.dznorm[exp.dznorm.muestra.str.contains(muestra.upper())].muestra.values[0]
fmu=exp.fmues[muestra_name]




plot1 = figure(x_axis_label='f[Hz]',y_axis_label='im(dz)/x0',height=altura,
               width=ancho, tools=tool_list,x_axis_type="log")
for n,fn in enumerate(fmu['fs']):
    x=fn
    ymeas=fmu['ymeas'][n]
    yteo=fmu['yteos'][n]
    plot1.scatter(x, ymeas,marker=markers[n],size=6,fill_alpha = 0)
    plot1.line(x=x, y=yteo, line_color="#f46d43", line_width=2, line_alpha=0.6)
show(plot1)
# Out:
#   <div id="74b2dc91-6c87-4ec2-8c1c-973a9cc4fed8" data-root-id="p7757" style="display: contents;"></div>

# %%
fmu['ymeas']
# Out:
# [array([0.10118972, 0.10089857, 0.10051273, 0.09981457, 0.09919751,
#         0.09817336, 0.09725091, 0.09565024, 0.09378866, 0.09294258,
#         0.09151042]),
#  array([0.08908558, 0.08725625, 0.08491174, 0.08246927, 0.07962528,
#         0.07627061, 0.0733562 , 0.0696977 , 0.06566357, 0.06125671]),
#  array([0.05607711, 0.052376  , 0.04700426, 0.04071382, 0.03605724,
#         0.02952567, 0.02270611, 0.01677428, 0.01048559, 0.004143  ])]

# %%
fmu['fs']
# Out:
# [array([ 1000.   ,  1258.925,  1584.893,  1995.262,  2511.886,  3162.278,
#          3981.072,  5011.872,  6309.574,  7943.282, 10000.   ]),
#  array([ 12589.25,  15848.93,  19952.62,  25118.86,  31622.78,  39810.72,
#          50118.73,  63095.73,  79432.82, 100000.  ]),
#  array([ 125892.5,  158489.3,  199526.2,  251188.6,  316227.8,  398107.2,
#          501187.2,  630957.3,  794328.3, 1000000. ])]

# %%
exp1=ci.exp('./iamend_ci/datos/pp1_1010')
exp1.fitmues()
# Out:
#              archivo  conductividad  espesor bobina muestras
# 0  Exp_1010_Aire.csv            0.0  0.00000    pp1     aire
# 1    Exp_1010_M0.csv      3830000.0  0.06500    pp1  1010_M0
# 2  Exp_1010_P057.csv      3948000.0  0.14957    pp1     P057
# Ajustando z1 effectivo
# z1 = 1.606773662019182 mm

# %%
n_splits_f=3
exp1.fitfmues(n_splits_f)
# Out:
# fiteo en N tramos

# %%
exp1.info
# Out:
#              archivo  conductividad  espesor bobina muestras      mueff  \
# 0  Exp_1010_Aire.csv            0.0  0.00000    pp1     aire        NaN
# 1    Exp_1010_M0.csv      3830000.0  0.06500    pp1  1010_M0  89.564698
# 2  Exp_1010_P057.csv      3948000.0  0.14957    pp1     P057        NaN
#
#          R2
# 0       NaN
# 1  0.988442
# 2       NaN

# %%
for fn in range(n_splits_f):
    fo=int(exp1.fmues['1010_M0']['fs'][fn][0]/1000)
    ff=int(exp1.fmues['1010_M0']['fs'][fn][-1]/1000)
    exp1.info.loc[exp1.info.muestras=='1010_M0','mu '+str(fo)+'k-'+str(ff)+'k']=exp1.fmues['1010_M0']['mues'][fn]

# %%
exp1.info
# Out:
#              archivo  conductividad  espesor bobina muestras      mueff  \
# 0  Exp_1010_Aire.csv            0.0  0.00000    pp1     aire        NaN
# 1    Exp_1010_M0.csv      3830000.0  0.06500    pp1  1010_M0  89.564698
# 2  Exp_1010_P057.csv      3948000.0  0.14957    pp1     P057        NaN
#
#          R2    mu 0k-1k   mu 2k-50k  mu 63k-1000k
# 0       NaN         NaN         NaN           NaN
# 1  0.988442  179.996371  124.081289     75.875761
# 2       NaN         NaN         NaN           NaN

# %%
for x in exp.fmues.keys():
    print(x)
# Out:
# 1010_M0

# %%
exp2=ci.exp('./iamend_ci/datos/m1_1010')
exp2.fitmues()
exp2.fitplot('m0')
# Out:
#              archivo  conductividad  espesor bobina muestras
# 0  Exp_1010_Aire.csv            0.0    0.000     m1     aire
# 1    Exp_1010_M0.csv      3830000.0    0.065     m1  1010_M0
# Ajustando z1 effectivo
# No se encuentra medicion sobre el patron, defina z1eff manualmente
# No existe la muestra, revise .info
