# %%
import iamend_ci as ci

exp1=ci.exp('.//iamend_ci//datos//m1_347')
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1001">Loading BokehJS ...</span>
#     </div>
#                  archivo  conductividad  espesor bobina
# 0       Exp_347_Aire.csv              0        0     m1
# 1        Exp_347_M01.csv              0        0     m1
# 2        Exp_347_M02.csv              0        0     m1
# 3        Exp_347_M03.csv              0        0     m1
# 4        Exp_347_M04.csv              0        0     m1
# 5        Exp_347_M05.csv              0        0     m1
# 6        Exp_347_M06.csv              0        0     m1
# 7        Exp_347_M07.csv              0        0     m1
# 8        Exp_347_M08.csv              0        0     m1
# ...

# %%
exp1.info
# Out:
#                  archivo  conductividad  espesor bobina
# 0       Exp_347_Aire.csv              0        0     m1
# 1        Exp_347_M01.csv              0        0     m1
# 2        Exp_347_M02.csv              0        0     m1
# 3        Exp_347_M03.csv              0        0     m1
# 4        Exp_347_M04.csv              0        0     m1
# 5        Exp_347_M05.csv              0        0     m1
# 6        Exp_347_M06.csv              0        0     m1
# 7        Exp_347_M07.csv              0        0     m1
# 8        Exp_347_M08.csv              0        0     m1
# 9        Exp_347_M09.csv              0        0     m1
# 10       Exp_347_M11.csv              0        0     m1
# 11  Exp_347_Patron78.csv              0        0     m1
# 12  Exp_347_Patron80.csv              0        0     m1

# %%
exp1.bobina
# Out:
# {'r1': 0.00115,
#  'r2': 0.00295,
#  'dh': 0.00248,
#  'N': 387,
#  'z1': 0.0007,
#  'L0': 0.00037575,
#  'R0': 14.55}

# %%
exp1.fitpatron(param_geo='N',plot=True)
# Out:
# N = 500.0
#   <div id="23eff2fa-24ee-4ee0-b21c-beb739963abd" data-root-id="p1179" style="display: contents;"></div>
# True

# %%
exp1.coil
# Out:
# [0.00115, 0.00295, 0.00248, 387, 0.0007, 14.55, 0.00037575]

# %%
exp1.data[0]
# Out:
# array([[1.00000000e+00, 2.00000000e+00, 3.00000000e+00, ...,
#         6.08000000e+02, 6.09000000e+02, 6.10000000e+02],
#        [1.00000000e+00, 1.00000000e+00, 1.00000000e+00, ...,
#         1.00000000e+01, 1.00000000e+01, 1.00000000e+01],
#        [1.00000000e+03, 1.12201800e+03, 1.25892500e+03, ...,
#         7.94328300e+05, 8.91250900e+05, 1.00000000e+06],
#        [1.46025600e+01, 1.46067500e+01, 1.45976700e+01, ...,
#         8.01023300e+01, 9.63157400e+01, 1.17371000e+02],
#        [2.36330200e+00, 2.65456700e+00, 2.97388700e+00, ...,
#         1.92616100e+03, 2.17835200e+03, 2.46368700e+03],
#        [6.28318531e+03, 7.04984701e+03, 7.91005906e+03, ...,
#         4.99091190e+06, 5.59989456e+06, 6.28318531e+06]])

# %%
exp1.normcorr()

# %%
exp1.dzcorrnorm[0].imag
# Out:
# array([ 6.47061524e-04,  8.55230294e-06,  8.03672750e-05, -2.30495873e-04,
#         3.27151911e-04, -3.52548365e-05, -1.11023377e-04,  2.91587568e-05,
#        -1.41280494e-05, -1.90922914e-04, -2.58902354e-04, -4.89436049e-04,
#        -1.71159420e-03, -8.69008328e-04, -1.66208072e-03, -2.06031918e-03,
#        -3.21017970e-03, -3.44208382e-03, -3.07178589e-03, -3.18805484e-03,
#        -3.97723115e-03, -5.43846434e-03, -6.73846457e-03, -7.27184884e-03,
#        -7.00920823e-03, -7.78297689e-03, -8.45058829e-03, -9.62025667e-03,
#        -1.04024163e-02, -1.19341911e-02, -1.30905406e-02, -1.42196100e-02,
#        -1.56508857e-02, -1.75980818e-02, -2.04886361e-02, -2.09083411e-02,
#        -2.32032937e-02, -2.56734308e-02, -2.64128299e-02, -2.88717385e-02,
#        -3.23863437e-02, -3.35871628e-02, -3.54097626e-02, -3.83808153e-02,
#        -4.07950790e-02, -4.38375934e-02, -4.50143077e-02, -4.58504105e-02,
# ...

# %%
exp1.im(5)

# %%
exp1.re(0)

# %%
exp1.fitpatron()
# Out:
# z1 = 1.0360259829448746 mm

# %%
exp1.z1eff
# Out:
# 0.001036025982944876

# %%
exp1.coil
# Out:
# [0.00115, 0.00295, 0.00248, 387, 0.001036025982944876, 14.55, 0.00037575]

# %%
exp1.fitmues()
# Out:
# mu_r_eff = 1.0042262193481575
# mu_r_eff = 7.272184589802646
# mu_r_eff = 6.199932827423396
# mu_r_eff = 5.763565791685518
# mu_r_eff = 5.704608859642888
# mu_r_eff = 4.92852182416232
# mu_r_eff = 2.3434934438683177

# %%
exp1.info
# Out:
#         archivo  conductividad   espesor bobina    mu_eff
# 0    0_aire.csv            0.0  0.000000     m1  0.000000
# 1  1_patron.csv       612000.0  0.025000     m1  1.004226
# 2  304_1_p1.csv      1040000.0  0.003737     m1  7.272185
# 3  304_1_p2.csv      1060000.0  0.003818     m1  6.199933
# 4  304_1_p3.csv      1140000.0  0.003842     m1  5.763566
# 5  304_1_p4.csv      1240000.0  0.003877     m1  5.704609
# 6  304_1_p5.csv      1260000.0  0.003899     m1  4.928522
# 7  304_1_p6.csv      1310000.0  0.004105     m1  2.343493

# %%
exp1.muesfigs[5]

# %%
exp2=ci.exp('/Users/fernando/Downloads/datos_perm_304-main/304_2')

# %%
exp2.info
# Out:
#         archivo  conductividad   espesor bobina
# 0    0_aire.csv            0.0  0.000000     m1
# 1  1_patron.csv       610200.0  0.025000     m1
# 2  304_2_p1.csv      1040000.0  0.003745     m1
# 3  304_2_p2.csv      1060000.0  0.003782     m1
# 4  304_2_p3.csv      1140000.0  0.003824     m1
# 5  304_2_p4.csv      1240000.0  0.003856     m1
# 6  304_2_p5.csv      1260000.0  0.003893     m1
# 7  304_2_p6.csv      1310000.0  0.004094     m1

# %%
exp2.normcorr()

# %%
exp2.fitpatron()
# Out:
# z1 = 1.0348044181290368 mm

# %%
exp2.fitmues()
# Out:
# mu_r_eff = 1.0039506993709484
# mu_r_eff = 6.746763257496928
# mu_r_eff = 6.353155459018081
# mu_r_eff = 6.328003766359283
# mu_r_eff = 6.175455537689974
# mu_r_eff = 6.002553554645885
# mu_r_eff = 3.180126531341221

# %%
exp2.info
# Out:
#         archivo  conductividad   espesor bobina    mu_eff
# 0    0_aire.csv            0.0  0.000000     m1  0.000000
# 1  1_patron.csv       610200.0  0.025000     m1  1.003951
# 2  304_2_p1.csv      1040000.0  0.003745     m1  6.746763
# 3  304_2_p2.csv      1060000.0  0.003782     m1  6.353155
# 4  304_2_p3.csv      1140000.0  0.003824     m1  6.328004
# 5  304_2_p4.csv      1240000.0  0.003856     m1  6.175456
# 6  304_2_p5.csv      1260000.0  0.003893     m1  6.002554
# 7  304_2_p6.csv      1310000.0  0.004094     m1  3.180127
